# %% [markdown]
# <a href="https://colab.research.google.com/github/tejascoder12/DSBD/blob/main/1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Uber Request Data.csv")

# %%
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
df.isnull()
# Out:
#       Request id  Pickup point  Driver id  Status  Request timestamp  \
# 0          False         False      False   False              False
# 1          False         False      False   False              False
# 2          False         False      False   False              False
# 3          False         False      False   False              False
# 4          False         False      False   False              False
# ...          ...           ...        ...     ...                ...
# 6740       False         False       True   False              False
# 6741       False         False       True   False              False
# 6742       False         False       True   False              False
# 6743       False         False       True   False              False
# 6744       False         False       True   False              False
#
#       Drop timestamp
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...

# %%
df.isnull().sum()
# Out:
# Request id              0
# Pickup point            0
# Driver id            2650
# Status                  0
# Request timestamp       0
# Drop timestamp       3914
# dtype: int64

# %%
df.describe()
# Out:
#         Request id    Driver id
# count  6745.000000  4095.000000
# mean   3384.644922   149.501343
# std    1955.099667    86.051994
# min       1.000000     1.000000
# 25%    1691.000000    75.000000
# 50%    3387.000000   149.000000
# 75%    5080.000000   224.000000
# max    6766.000000   300.000000

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.head(10)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 5        3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6        4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# 7        5510      Airport        1.0  Trip Completed  15-07-2016 05:11:52
# 8        6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9         267         City        2.0  Trip Completed       11/7/2016 6:46
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# ...

# %%
df.tail()
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 6740  15-07-2016 23:49:03            NaN
# 6741  15-07-2016 23:50:05            NaN
# 6742  15-07-2016 23:52:06            NaN
# 6743  15-07-2016 23:54:39            NaN
# 6744  15-07-2016 23:55:03            NaN

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Length: 150, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-d54188136223> in <module>
# ----> 1 df.isnull.isna().sum()
#
# AttributeError: 'function' object has no attribute 'isna'

# %%
df.iloc[:,:4]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.petal_length.sum()
# Out:
# 563.8

# %%
df.groupby(['sepal_length'])['petal_width'].apply(lambda x:x.isnull().sum())
# Out:
# sepal_length
# 4.3    0
# 4.4    0
# 4.5    0
# 4.6    0
# 4.7    0
# 4.8    0
# 4.9    0
# 5.0    0
# 5.1    0
# 5.2    0
# 5.3    0
# 5.4    0
# 5.5    0
# 5.6    0
# 5.7    0
# 5.8    0
# 5.9    0
# 6.0    0
# 6.1    0
# 6.2    0
# 6.3    0
# 6.4    0
# 6.5    0
# 6.6    0
# 6.7    0
# 6.8    0
# 6.9    0
# 7.0    0
# 7.1    0
# 7.2    0
# 7.3    0
# 7.4    0
# 7.6    0
# 7.7    0
# 7.9    0
# Name: petal_width, dtype: int64

# %%
df.groupby(['sepal_length'])['petal_width'].apply(lambda x:x.isnull().sum())
# Out:
# sepal_length
# 4.3    0
# 4.4    0
# 4.5    0
# 4.6    0
# 4.7    0
# 4.8    0
# 4.9    0
# 5.0    0
# 5.1    0
# 5.2    0
# 5.3    0
# 5.4    0
# 5.5    0
# 5.6    0
# 5.7    0
# 5.8    0
# 5.9    0
# 6.0    0
# 6.1    0
# 6.2    0
# 6.3    0
# 6.4    0
# 6.5    0
# 6.6    0
# 6.7    0
# 6.8    0
# 6.9    0
# 7.0    0
# 7.1    0
# 7.2    0
# 7.3    0
# 7.4    0
# 7.6    0
# 7.7    0
# 7.9    0
# Name: petal_width, dtype: int64

# %%
df.groupby(['species'])dth'].apply(lambda x:x.sum())
# Out:
#   File "<ipython-input-32-afddf59becdc>", line 1
#     df.groupby(['species'])dth'].apply(lambda x:x.sum())
#                            ^
# SyntaxError: invalid syntax
